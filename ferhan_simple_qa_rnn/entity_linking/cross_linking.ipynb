# %%
import os
import sys
import argparse
import pickle
import math
import unicodedata
import pandas as pd
import numpy as np

from fuzzywuzzy import fuzz
from nltk.tokenize.treebank import TreebankWordTokenizer
from nltk.corpus import stopwords

# %%
# arguments
index_entpath = "../indexes/entity_2M.pkl"
index_reachpath = "../indexes/reachability_2M.pkl"
index_namespath = "../indexes/names_2M.pkl"
ent_resultpath = "../entity_detection/query-text/val.txt"
rel_resultpath = "../relation_prediction/results/topk-retrieval-valid-hits-3.txt"
outpath = "./tmp/results"

# %%
tokenizer = TreebankWordTokenizer()
stopwords = set(stopwords.words('english'))

def tokenize_text(text):
    tokens = tokenizer.tokenize(text)
    return tokens

def www2fb(in_str):
    if in_str.startswith("www.freebase.com"):
        return 'fb:%s' % (in_str.split('www.freebase.com/')[-1].replace('/', '.'))
    return in_str

def get_index(index_path):
    print("loading index from: {}".format(index_path))
    with open(index_path, 'rb') as f:
        index = pickle.load(f)
    return index

def strip_accents(text):
    return ''.join(c for c in unicodedata.normalize('NFKD', text) if unicodedata.category(c) != 'Mn')

# %%
def get_query_text(ent_resultpath):
    print("getting query text...")
    lineids = []
    id2query = {}
    notfound = 0
    with open(ent_resultpath, 'r') as f:
        for line in f:
            items = line.strip().split(" %%%% ")
            try:
                lineid = items[0].strip()
                query = items[1].strip()
                # mid = items[2].strip()
            except:
                # print("ERROR: line does not have >2 items  -->  {}".format(line.strip()))
                notfound += 1
                continue
            # print("{}   -   {}".format(lineid, query))
            lineids.append(lineid)
            id2query[lineid] = query
    print("notfound (empty query text): {}".format(notfound))
    return lineids, id2query

def get_relations(rel_resultpath):
    print("getting relations...")
    lineids = []
    id2rels = {}
    with open(rel_resultpath, 'r') as f:
        for line in f:
            items = line.strip().split(" %%%% ")
            lineid = items[0].strip()
            rel = www2fb(items[1].strip())
            label = items[2].strip()
            score = items[3].strip()
            # print("{}   -   {}".format(lineid, rel))
            if lineid in id2rels.keys():
                id2rels[lineid].append( (rel, label, score) )
            else:
                id2rels[lineid] = [(rel, label, score)]
                lineids.append(lineid)
    return lineids, id2rels

# %%
_, tmp = get_relations(rel_resultpath)
tmp['valid-1']
# Out:
# getting relations...
# [('fb:symbols.namesake.named_after', '1', '-0.9163265228271484'),
#  ('fb:protected_sites.protected_site.governing_body',
#   '0',
#   '-2.0246400833129883'),
#  ('fb:sports.professional_sports_team.owner_s', '0', '-2.1866111755371094')]

# %%
def find_ngrams(input_list, n):
    ngrams = zip(*[input_list[i:] for i in range(n)])
    return set(ngrams)

# %%
def calc_tf_idf(query, cand_ent_name, cand_ent_count, num_entities, index_ent):
    query_terms = tokenize_text(query)
    doc_tokens = tokenize_text(cand_ent_name)
    common_terms = set(query_terms).intersection(set(doc_tokens))

    # len_intersection = len(common_terms)
    # len_union = len(set(query_terms).union(set(doc_tokens)))
    # tf = len_intersection / len_union
    tf = math.log10(cand_ent_count + 1)
    k1 = 0.5
    k2 = 0.5
    total_idf = 0
    for term in common_terms:
        df = len(index_ent[term])
        idf = math.log10( (num_entities - df + k1) / (df + k2) )
        total_idf += idf
    return tf * total_idf

# %%
#outfile = open(os.path.join(outpath, "linking-results.txt"), 'w')
notfound_ent = 0
notfound_c = 0

index_ent = get_index(index_entpath)
num_entities_fbsubset = 1959820  # 2M - 1959820 , 5M - 1972702
# Out:
# loading index from: ../indexes/entity_2M.pkl

# %%
index_names = get_index(index_namespath)
# Out:
# loading index from: ../indexes/names_2M.pkl

# %%
index_reach = get_index(index_reachpath)
# Out:
# loading index from: ../indexes/reachability_2M.pkl

# %%
def pick_best_name(question, names_list):
    best_score = None
    best_name = None
    for name in names_list:
        score =  fuzz.ratio(name, question)
        if best_score == None or score > best_score:
            best_score = score
            best_name = name

    return best_name

# %%
rel_lineids, id2rel = get_relations(rel_resultpath)
ent_lineids, id2query = get_query_text(ent_resultpath)  # ent_lineids may have some examples missing
# Out:
# getting relations...
# getting query text...
# notfound (empty query text): 0

# %%
def get_questions(datapath):
    print("getting questions...")
    id2question = {}
    with open(datapath, 'r') as f:
        for line in f:
            items = line.strip().split("\t")
            lineid = items[0].strip()
            sub = items[1].strip()
            pred = items[2].strip()
            obj = items[3].strip()
            question = items[4].strip()
            # print("{}   -   {}".format(lineid, question))
            if lineid.startswith("valid"):
                id2question[lineid] = (sub, pred, question)
    return id2question

datapath = "../data/SimpleQuestions_v2_modified/all.txt"
id2question = get_questions(datapath)
print(len(id2question))
print(id2question['valid-1'])
# Out:
# getting questions...
# 10845
# ('fb:m.0f3xg_', 'fb:symbols.namesake.named_after', 'Who was the trump ocean club international hotel and tower named after')

# %%
def get_docs(query):
    docids = index_ent[query]
    docs = []
    for id in docids:
        try:
            docs.append( (id, index_names[id]) )
        except:
            continue
    return docs

# %%
get_docs("sasha")
# Out:
# [('fb:m.0c6kfg',
#   ["natasha `` sasha '' williams craig",
#    'sasha williams',
#    'sasha craig',
#    'natasha williams']),
#  ('fb:m.03qmf6n', ['sasha siemel']),
#  ('fb:m.06w878', ['sasha embeth pieterse', 'sasha pieterse']),
#  ('fb:m.0p8vmp',
#   ['ray of light ( ultra violet mix )',
#    'ray of light ( sasha ultra violet mix )']),
#  ('fb:m.0gcbt_y',
#   ['natasha angelety', 'sasha angeletti', "natasha `` sasha '' angelety"]),
#  ('fb:m.03c8k07', ['sasha krasny']),
#  ('fb:m.0hy_626',
#   ['ante marich darko',
#    "sasha d'ark",
#    'hydrian darko',
#    "sasha d'arc",
#    'hadryan darka',
#    'sasha c. darko',
#    'sacha dark']),
#  ('fb:m.03ckj5b', ['sasha toperich', 'sasa toperic', 'sasa toperic']),
#  ('fb:m.0bflz9y', ['sasha ambak', 'sacha amback']),
#  ('fb:m.05syhsf', ['sasha roiz']),
#  ('fb:m.01hw40t',
#   ['global underground 009',
#    'global underground 003 : sasha in san francisco',
#    'global underground 009 : sasha in san francisco']),
#  ('fb:m.04hy_nc', ['sasha gabriella fox']),
#  ('fb:m.0g41jtl', ['sasha andreev']),
#  ('fb:m.0h8k5mx', ['alexander golberg', 'sasha golberg']),
#  ('fb:m.01sn21k', ['sasha', 'sascha', 'dick brave', 'sascha schmitz']),
#  ('fb:m.0v35082',
#   ['alexander mandra',
#    'olexander mandra',
#    'olexandr mandra',
#    'sasha mandra',
#    'alex mandra',
#    'alexander sasha mandra']),
#  ('fb:m.02nqgyw', ['sasha obama', 'natasha obama']),
#  ('fb:m.01s4267', ['sasha & digweed , john', 'sasha & john digweed']),
#  ('fb:m.0lg2qvz', ['sasha van bon bon']),
#  ('fb:m.03pkzn',
#   ['alexander popov',
#    'the russian rocket',
#    'aleksandr popov',
#    'the tsar of swimming',
#    'alexander popov',
#    'alexander vladimirovich popov',
#    'sasha']),
#  ('fb:m.0gbwtkc',
#   ['aleksandr aleksandrovich ilyin',
#    'a. ilyin',
#    'aleksandr ilyin jr.',
#    'aleksandr ilyin',
#    'alexandr ilyin',
#    'alexander ilyin',
#    'sasha ilin',
#    'a.ilyin',
#    'aleksandr ilin']),
#  ('fb:m.0fj1h6', ['sasha gotsmanov']),
#  ('fb:m.0b6kc5',
#   ['sasha', 'lazard , sasha', 'dominique lazard', 'sasha lazard']),
#  ('fb:m.0c6q_x', ['sasha paysinger']),
#  ('fb:m.0ndd219', ['sasha collington']),
#  ('fb:m.0qc4n3_', ['sasha raskin']),
#  ('fb:m.01w8s4d',
#   ['dj sasha',
#    'sasha rosenhouse',
#    'alexander paul coe',
#    'sasha',
#    'alexander coe']),
#  ('fb:m.03_jtzz', ['global underground 003 : sasha in san francisco']),
#  ('fb:m.0by3hc',
#   ['elektra blue',
#    'sasha clifford',
#    'sasha blue',
#    'alectra',
#    'alektra blue',
#    'alectra blue',
#    'alektra blu',
#    'alektra']),
#  ('fb:m.04jdfdv',
#   ['marianna',
#    'martha',
#    'tarra white',
#    'terra white',
#    'chrissy',
#    'tara',
#    'terra',
#    'martina hlavacs mrakviova',
#    'taylor',
#    'martina',
#    'sasha jezel',
#    'martina mrakviova',
#    'ondreja',
#    'tara white',
#    'susie',
#    'tarra',
#    'martinka pipinkova',
#    'layla lee',
#    'tarra light']),
#  ('fb:m.0h1gpzr',
#   ['sasha alexander aneff medrano rosso',
#    'sasha aneff-medrano',
#    'sasha aneff',
#    'sasha alexander aneff']),
#  ('fb:m.0cgsqk',
#   ['alexander siegfried georg smahel',
#    'alexandr hackenschmied',
#    'sasha hammid',
#    'alexander hackensmid',
#    'alexander hackenschmied',
#    'alexander hackenschmidt',
#    'alexander hackenschmid',
#    'alexander hackeschmied',
#    'alexander hamid',
#    'alexander hammid']),
#  ('fb:m.03cc9f4', ['sasa yunisoglu', 'sascha yunisoglu', 'sasha yunisoglu']),
#  ('fb:m.0z_n1gn', ['sasha charkin']),
#  ('fb:m.0h297xg', ['sasha dylan bell']),
#  ('fb:m.0gbxms7', ['sacha andres', 'sasha andres', 'sasha andres']),
#  ('fb:m.0gsybm4',
#   ['sasha rukavina', 'sacha rvkavkna', 'sasha rucavina', 'sacha rukavina']),
#  ('fb:m.0cr5_v',
#   ['sasha frere-jones',
#    'frere-jones , sasha',
#    'alexander roger wallace jones']),
#  ('fb:m.0jb9y67', ['sasha wells']),
#  ('fb:m.02pqvtr', ['sasha ivanov']),
#  ('fb:m.033psnz',
#   ['global underground 009 : sasha in san francisco',
#    'global underground 009 : sasha in san francisco ( disc 2 )']),
#  ('fb:m.0n5bs9q',
#   ['aleksandr zavyalov',
#    'sasha zavialo',
#    'sasha zavyalov',
#    "alexander zav'yalov"]),
#  ('fb:m.09kh8_', ['sasha close']),
#  ('fb:m.063wpg6', ['sasha', 'sasha martin']),
#  ('fb:m.0h88bb2',
#   ['sasha puttnam',
#    'alexander puttnam',
#    'sacha putnam',
#    'putnam , sacha',
#    'sacha puttnam',
#    'sasha putnam',
#    'sacha putnam',
#    'puttnam , sacha',
#    'alexander david puttnam']),
#  ('fb:m.0clqvvj', ['sasha pirker']),
#  ('fb:m.0tkkp9j', ['sasha agha', 'zara agha khan']),
#  ('fb:m.0v92plg', ['sasha foer']),
#  ('fb:m.0lbc0dt',
#   ['aleksandr valeryevich nosik',
#    'sasha nosik',
#    'aleksandr nosik',
#    'alexander nosik']),
#  ('fb:m.0jqzd4m',
#   ['alexander ilyin',
#    'aleksandr ilin',
#    'alexander ilyn',
#    'a. ilin',
#    'sasha ilin',
#    'a.ilyin',
#    'aleksandr ilin st.',
#    'alexandre ilyne',
#    'a. ilyin',
#    'aleksandr ilyin']),
#  ('fb:m.02qps6c',
#   ["`` sasha '' gabor sarkozi",
#    'turd wrenolds',
#    'gabor sarkøzy',
#    'sasha',
#    'sascha',
#    'sacha gabor',
#    "alexander 'sasha ' gabor",
#    'james bandit',
#    'gabor sarkozi',
#    'sasha gabor',
#    'sascha gabor']),
#  ('fb:m.09myxl', ['sasha sokolov']),
#  ('fb:m.0c489mr', ['sasha moorsom young', 'sasha moorsom']),
#  ('fb:m.03yg5gn', ['3680 sasha', '1987 my']),
#  ('fb:m.076gpk', ['sasha singleton']),
#  ('fb:m.0r9f',
#   ['alexander iii of russia',
#    'alexander the peacemaker',
#    'sasha',
#    'alexander alexandrovich',
#    'czar aleksandr iii',
#    'alexander alexandrovich romanov',
#    'tsar alexander iii',
#    'александр александрович']),
#  ('fb:m.0kfbbl6', ['sasha friedlander']),
#  ('fb:m.0k2gg14',
#   ['sascha', 'sasha libido', 'sascha benjamin koch', 'sacha', 'sasha']),
#  ('fb:m.086t5y', ['sasha bordeaux']),
#  ('fb:m.026c6lr',
#   ['sasha gray',
#    'anna karina',
#    'marina ann hantzis',
#    'sascha grey',
#    'sasha',
#    'the erotic enigma',
#    'sasha grey',
#    'סאשה גריי']),
#  ('fb:m.032wwh',
#   ['belladonna',
#    'michelle sinclair',
#    'sasha',
#    'bella',
#    'michelle anne sinclair',
#    'bella donna',
#    'belladonna']),
#  ('fb:m.0fvr5c5', ['earthquake ( sasha remix )']),
#  ('fb:m.0_m1n_2', ['fuck : sasha grey']),
#  ('fb:m.0dnz93s', ['ray of light ( sasha strip down mix )']),
#  ('fb:m.0h5d5m3', ['alexandra zoe cassavetes', 'sasha cassavetes']),
#  ('fb:m.02qkk2s',
#   ['silver stacy',
#    'dana mandatova',
#    'stacy',
#    'donna tova',
#    'dana m.',
#    'staci silver',
#    'sabrina love-cox',
#    'dana a.',
#    'stacy lovecock',
#    'danecka mandatova',
#    'judit',
#    'stacy silver',
#    'dana',
#    'sasha',
#    'julie',
#    'stacey silver']),
#  ('fb:m.0nk_g6n', ['underdog ( sasha remix )']),
#  ('fb:m.05b1qyp', ['sasha mcdonnell']),
#  ('fb:m.088d72', ['alexander zemlianichenko', 'sasha zemlianichenko']),
#  ('fb:m.0gbx3w2',
#   ['sasha darwin',
#    'sacha davidof',
#    'sacha m. darwin',
#    'sacha maria darwin',
#    'sacha darwin',
#    'sascha maria albach-retty']),
#  ('fb:m.0t_5mg5', ['aleksandr akulov', 'sasha']),
#  ('fb:m.04p27k',
#   ['a. chanshonkov',
#    'sasha',
#    'aleksandr aleksejevich khanzhonkov',
#    'aleksandr alekseevich khanzhonkov',
#    'aleksandr khanzhonkov']),
#  ('fb:m.05zqng5', ['sasha jackson']),
#  ('fb:m.0b_zz73', ['sasa', 'sascha', 'sasha', 'sasa']),
#  ('fb:m.0h1c45j',
#   ['alexander abramovich',
#    "alexander `` sasha '' argov",
#    'alexander argov',
#    'sasha argov']),
#  ('fb:m.0bdv8c_',
#   ['alexandra sagan',
#    'sasha sagan',
#    "alexandra rachel `` sasha '' druyan sagan"]),
#  ('fb:m.0j8ktz5', ['a. samoylov', 'aleksandr samoylov', 'sasha samoylov']),
#  ('fb:m.0741jp',
#   ['alexandra tolstoy',
#    'aleksandra lvovna tolstoy',
#    'alexandra tolstaya',
#    'alexandra lvovna tolstaya',
#    'александра львовна толстая',
#    'aleksandra tolstaya',
#    'sasha']),
#  ('fb:m.02b5m2',
#   ["alexandre `` sacha '' trudeau",
#    'alexandre trudeau',
#    'alexandre emmanuel trudeau',
#    'sasha',
#    'sacha',
#    'sacha trudeau']),
#  ('fb:m.0bmbj63', ['sasha strunin', 'alexandra strunin']),
#  ('fb:m.0ddh3z_', ['eduardo sasha', 'eduardo colcenti antunes']),
#  ('fb:m.02rjzqb',
#   ['out of control ( sasha remix )',
#    'out of control',
#    'out of control ( feat. bernard sumner & bobby gillespie )',
#    'out of control ( sasha instrumental mix )']),
#  ('fb:m.0wj6_xs', ['belfast ( sasha remix )']),
#  ('fb:m.0n50x53', ['alexander sasha burton', 'alex burton']),
#  ('fb:m.0b9kqj',
#   ['sasha barrese', 'alexandra barrese', "alexandra `` sasha '' barrese"]),
#  ('fb:m.0xmrgvx', ['primera fila : sasha benny erik']),
#  ('fb:m.04zzh42', ['sasha waltz']),
#  ('fb:m.0t5cxv2',
#   ['sasha meneghel', 'sasha meneghel', 'sasha meneghel szafir']),
#  ('fb:m.01wn76f', ['karen chin', 'sasha']),
#  ('fb:m.04cgjl', ['sasha victorine']),
#  ('fb:m.0jwdws1', ['aleksandr loye', 'sasha loye']),
#  ('fb:m.0k3qsgz', ['sasha knezev']),
#  ('fb:m.026wgl7',
#   ['alekandar petrovic',
#    'a. petrovic',
#    'aleksandar petrovic',
#    "aleksandar `` sasa '' petrovic",
#    'petrovich aleksandar',
#    'aleksandar sacha petrovitch',
#    'aleksander petkovic',
#    'sasha petrovich']),
#  ('fb:m.0cbfvr7',
#   ['aleksandr buravskiy',
#    'aleksandr mironovich buravsky',
#    'aleksandr buravsky',
#    'sasha buravsky']),
#  ('fb:m.0dtzbhb', ['ray of light ( sasha twilo mix )']),
#  ('fb:m.04y6901', ['sasha siem']),
#  ('fb:m.0v2dj9x', ['sasha mesina']),
#  ('fb:m.0h28mw9',
#   ['sacha ( alexander ) newley',
#    'sasha',
#    "alexander anthony `` sacha '' newley",
#    "alexander anthony 'sacha ' newley",
#    'alexander newley',
#    'sacha newley',
#    'alexander anthony newley']),
#  ('fb:m.0gcfxhw',
#   ['aleksandr potapov',
#    'sasha',
#    'a. potapov',
#    'aleksandr sergeyevich potapov',
#    'aleksandr sergeevich potapov']),
#  ('fb:m.0277z9j', ['sasha kolpakov']),
#  ('fb:m.0c264t',
#   ['sasha kaun',
#    'alexandr kaun',
#    'alexander kaun',
#    'alexander olegovich kaun']),
#  ('fb:m.0rdc4v_', ['aleksandr', 'sasha', 'alexander']),
#  ('fb:m.0smys98', ['sasha , benny y erik']),
#  ('fb:m.05h3cm8', ['sasha song', 'son , sasha', 'sasha son']),
#  ('fb:m.0tllpr6', ['aleksandr volkov', 'sasha volkov']),
#  ('fb:m.03hl_kw', ['sasha putrya']),
#  ('fb:m.05zqvbh', ['sasha andrews']),
#  ('fb:m.09d8lv', ['sasha jenson', 'sasha jensen']),
#  ('fb:m.025y60l', ['sasha behar']),
#  ('fb:m.0gxnmys', ['sasha rovin']),
#  ('fb:m.0dgn58t', ['ranjini', 'renjini', 'sasha selvaraj', 'ranjani']),
#  ('fb:m.0lrp3k8', ['sasha popove', 'sasha a. popove']),
#  ('fb:m.03w96l0', ['sasha gradiva']),
#  ('fb:m.02_x7f2',
#   ['sasha stallone',
#    'sasha czack',
#    'sasha ash',
#    'sasha czack-stallone',
#    'sasha czack-ash',
#    'stitch',
#    'alexandra jane czack']),
#  ('fb:m.0yqnlyn', ['sasha hupman']),
#  ('fb:m.0g7s7dd', ['i am... sasha fierce']),
#  ('fb:m.0gc7byc', ['sasha toro']),
#  ('fb:m.0qjwv9b', ['flutes ( sasha remix )']),
#  ('fb:m.01pntlr',
#   ['sasha sokol', 'sasha marianne sokol cuillery', 'sokol , sasha']),
#  ('fb:m.03h_vsf', ['sasha', 'alexander schneider', 'abram sznejder']),
#  ('fb:m.05zmytw', ['aleksandr anttilainen', 'sasha anttilainen']),
#  ('fb:m.09g6m2l', ['sasha balych', 'sasa balic', 'sasa balic']),
#  ('fb:m.0gcc8r2',
#   ['sasha von scherler',
#    'alexandra xenia elizabeth anne marie fiesola von schoeler']),
#  ('fb:m.0q35ylm', ['alexandra lipskaia', 'sasha lipskaia']),
#  ('fb:m.02_ynt0',
#   ['alexander pete schreiber', 'sasha', "alexander `` sasha '' pete"]),
#  ('fb:m.07qn83', ['черныи , саша', 'sasha cherny']),
#  ('fb:m.075q9bm', ['sasha wolf']),
#  ('fb:m.0f5y13w', ['belfast ( sasha vs. the light remix )']),
#  ('fb:m.0277s3b',
#   ['sasha lakovic', "sasha `` the basha , pitbull '' lakovic", 'pit bull']),
#  ('fb:m.0jwggzb', ['sasha waters', 'sasha waters freyer']),
#  ('fb:m.0f9q98', ['sasha & john digweed present delta heavy']),
#  ('fb:m.0bl26k', ['sasha perera']),
#  ('fb:m.0sg_2k_',
#   ['alex gilbert',
#    'guzovskoy alexander viktorovich',
#    'sasha alexander gilbert']),
#  ('fb:m.0dgd4v', ['sasha pivovarova']),
#  ('fb:m.0t_8nly', ['sasha wexler']),
#  ('fb:m.01hw4ct',
#   ['global underground 013 : sasha in ibiza', 'global underground 013']),
#  ('fb:m.03d5d7h',
#   ['sasha sitkovetsky', 'sitkovetsky , alexander', 'alexander sitkovetsky']),
#  ('fb:m.0h_fxgv', ['sasha bragowa', 'lena malena']),
#  ('fb:m.02rqqy4', ['sasha issenberg']),
#  ('fb:m.0b73pyc', ['sasha rebecca spielberg', 'sasha spielberg']),
#  ('fb:m.0k19dcz',
#   ['sash', 'sasha jade azevedo', 'sassy', 'sasha azevedo', 'sasha jade']),
#  ('fb:m.03z1cn',
#   ['sasha alexander',
#    'suzana drobnjakovic',
#    'suzana drobnjakovic',
#    'suzana s. drobnjakovic']),
#  ('fb:m.0d_rz3v', ['belfast ( sasha vs. the light remix )']),
#  ('fb:m.040qyz', ['sasha cohen', 'alexandra pauline cohen']),
#  ('fb:m.07f3jg',
#   ['sasha vujacic', 'sasha vujacic', "aleksandar `` sasha '' vujacic"]),
#  ('fb:m.03_jv1t', ['global underground 013 : sasha in ibiza']),
#  ('fb:m.0k8034', ['sasha neulinger', 'sasha joseph neulinger']),
#  ('fb:m.0j7z3m7', ['sasha mchale', 'alexandra mchale']),
#  ('fb:m.0flp_12', ['belfast ( sasha vs. the light remix )']),
#  ('fb:m.03fzjzs', ['global underground 003 : sasha in san francisco']),
#  ('fb:m.0gcx7n9',
#   ['sasha mihaela oros',
#    'mihaela oros',
#    'mihaela elena oros',
#    "mihaela 'sasha ' oros"]),
#  ('fb:m.05yvdyy', ['sasha alpert']),
#  ('fb:m.01vg7c1', ['sasha allen']),
#  ('fb:m.0_shq5j', ['sasha vitelli']),
#  ('fb:m.04n32pn',
#   ['i am ... sasha fierce : the bonus tracks',
#    'i am...',
#    'i am ... sasha fierce']),
#  ('fb:m.04cxg5y',
#   ['sasha', 'anthea redfearn', 'anthea redfern', 'anthea bernice redfern']),
#  ('fb:m.07jlhm',
#   ['aleksandar pavlovic',
#    'sasha pavlovic',
#    'aleksandar pavlovic',
#    'aleksandar pavlovic']),
#  ('fb:m.05c3t85', ['sasha skenderija']),
#  ('fb:m.047byq4', ['sasha hollander']),
#  ('fb:m.0h77123', ['sasha levinson', 's. levinson', 'sasha']),
#  ('fb:m.027qk4',
#   ['sasha',
#    'александр борисович годунов',
#    'aleksander borisovich godunov',
#    'alexander borisovich godunov',
#    'aleksandr godunov',
#    'alexander godunov',
#    'sascha']),
#  ('fb:m.03rjhx', ['sash', 'sasha mitchell']),
#  ('fb:m.04w47v7', ['sasha and the wiggly tooth']),
#  ('fb:m.01mpq7s',
#   ['juju',
#    'mothe',
#    'beyonce giselle knowles',
#    'sasha fierce',
#    'bee',
#    'queen b',
#    'bey',
#    'beyonce giselle knowles-carter',
#    'beyonce knowles',
#    'beyonce knowles-carter',
#    'beyonce knowles',
#    'beyonce',
#    'beyonce']),
#  ('fb:m.0gsy3mw',
#   ['aleksandra kulikova', 'sasha kulikova', 'alexandra kulikova']),
#  ('fb:m.06yzqj',
#   ['ray of light ( victor calderone club mix )',
#    'ray of light ( victor calderone drum mix )',
#    'ray of light ( william orbit ultra violet mix )',
#    'ray of light ( sasha twilo mix )',
#    'ray of light ( ultra violet mix )',
#    'ray of light ( sasha ultra violet mix )',
#    'ray of light ( album version )',
#    'ray of light',
#    'ray of light ( william orbit liquid mix )',
#    'ray of light ( sasha strip down mix )',
#    'ray of light ( radio edit )']),
#  ('fb:m.0h97kr7',
#   ['sipiagin , alex', "alex `` sasha '' sipiagin", 'alex sipiagin']),
#  ('fb:m.0ynr__n', ['sasha'])]

# %%
print(len(id2query))
print(len(id2rel))
# Out:
# 10845
# 10845

# %%
index_ent["carlos"]
# Out:
# {'fb:m.0g7xb2s',
#  'fb:m.0fr_dx',
#  'fb:m.09v1qpp',
#  'fb:m.02pjqvs',
#  'fb:m.0hzrhcm',
#  'fb:m.0dfr9',
#  'fb:m.0glphxj',
#  'fb:m.09m7by',
#  'fb:m.02ppznz',
#  'fb:m.0crzp4v',
#  'fb:m.030tb6',
#  'fb:m.0yqdrb6',
#  'fb:m.0zmvsdf',
#  'fb:m.0bdwgdm',
#  'fb:m.0h4yp86',
#  'fb:m.06znnzy',
#  'fb:m.01jb8mq',
#  'fb:m.032pg9',
#  'fb:m.0bdq00',
#  'fb:m.04n35ks',
#  'fb:m.03gkyq',
#  'fb:m.05zp8v5',
#  'fb:m.07lmtcc',
#  'fb:m.086yr',
#  'fb:m.0gd2yf8',
#  'fb:m.09zkqb',
#  'fb:m.0jmqp_b',
#  'fb:m.0hp1vy3',
#  'fb:m.0808rb2',
#  'fb:m.0b73zb',
#  'fb:m.047nwxs',
#  'fb:m.04x5g_',
#  'fb:m.050lg7',
#  'fb:m.058d5x3',
#  'fb:m.02ppz6j',
#  'fb:m.0961k9',
#  'fb:m.0swmq0r',
#  'fb:m.0cc6y7h',
#  'fb:m.0s8vq8x',
#  'fb:m.07nlpq',
#  'fb:m.01jb6n0',
#  'fb:m.08m79rm',
#  'fb:m.0zhn7yy',
#  'fb:m.0vxpdzx',
#  'fb:m.026vh8v',
#  'fb:m.02yt_p',
#  'fb:m.02vnbts',
#  'fb:m.04ljsfy',
#  'fb:m.0ckwk7',
#  'fb:m.0289y4n',
#  'fb:m.03_5jy',
#  'fb:m.0pxcb64',
#  'fb:m.0lz0_xt',
#  'fb:m.04w_c6',
#  'fb:m.05pxzh6',
#  'fb:m.03crtk3',
#  'fb:m.074b5f',
#  'fb:m.04rvzt',
#  'fb:m.04ct002',
#  'fb:m.03cfnqn',
#  'fb:m.0cr1hv',
#  'fb:m.05w14v',
#  'fb:m.04crkxk',
#  'fb:m.04z_lxf',
#  'fb:m.0641tsk',
#  'fb:m.03h27g7',
#  'fb:m.0l4s8l0',
#  'fb:m.0gcf7z1',
#  'fb:m.06zlybp',
#  'fb:m.0gfrwxt',
#  'fb:m.02839yz',
#  'fb:m.05fbjyd',
#  'fb:m.01vz7ff',
#  'fb:m.047cdpb',
#  'fb:m.0cr_j1v',
#  'fb:m.0cz84g0',
#  'fb:m.02vxvkw',
#  'fb:m.03gsmmr',
#  'fb:m.03ycxbd',
#  'fb:m.02896dk',
#  'fb:m.02vzz4g',
#  'fb:m.09pxlr',
#  'fb:m.0462gmv',
#  'fb:m.0ph47mj',
#  'fb:m.0gcg0sh',
#  'fb:m.0g4p33q',
#  'fb:m.03cfw3x',
#  'fb:m.04sff1_',
#  'fb:m.03c03kz',
#  'fb:m.0h2m7vl',
#  'fb:m.07j0xv',
#  'fb:m.028srd',
#  'fb:m.0b9687',
#  'fb:m.0143m_',
#  'fb:m.0jtny0',
#  'fb:m.0f12v7d',
#  'fb:m.0kvdzkl',
#  'fb:m.04q272x',
#  'fb:m.02q0fr9',
#  'fb:m.0bh7bzs',
#  'fb:m.0w7p4x1',
#  'fb:m.05szzpt',
#  'fb:m.09v3wj0',
#  'fb:m.02ryrd3',
#  'fb:m.06zm_cv',
#  'fb:m.0g50f1',
#  'fb:m.02qrdkq',
#  'fb:m.0jzj4dk',
#  'fb:m.05my03r',
#  'fb:m.0_sqngx',
#  'fb:m.0bngf7',
#  'fb:m.0nf14ky',
#  'fb:m.04_0jk3',
#  'fb:m.0fbq6g',
#  'fb:m.02vsjy0',
#  'fb:m.05f9byq',
#  'fb:m.0l7xkbr',
#  'fb:m.0jqyxgr',
#  'fb:m.03hfww8',
#  'fb:m.0jqzz9q',
#  'fb:m.04p1ct',
#  'fb:m.0b___qc',
#  'fb:m.0cmdm89',
#  'fb:m.09dw3_4',
#  'fb:m.0zdhjz4',
#  'fb:m.02868ny',
#  'fb:m.02chjpy',
#  'fb:m.02rjs3y',
#  'fb:m.0wqfv3l',
#  'fb:m.05kkjn',
#  'fb:m.072wwm',
#  'fb:m.07jg3g',
#  'fb:m.09kqfk',
#  'fb:m.0b_lcs',
#  'fb:m.05n02xl',
#  'fb:m.0h17fg',
#  'fb:m.0pl4c7_',
#  'fb:m.02mzy_',
#  'fb:m.04p60cs',
#  'fb:m.0pyq_',
#  'fb:m.04816b',
#  'fb:m.0hgq5b1',
#  'fb:m.02wx9x',
#  'fb:m.0407wq0',
#  'fb:m.0jvbxvj',
#  'fb:m.0416x1g',
#  'fb:m.0crw65_',
#  'fb:m.0h7nf3b',
#  'fb:m.01t0d8m',
#  'fb:m.0h6s2_',
#  'fb:m.05zvjlf',
#  'fb:m.07r4f1',
#  'fb:m.0gjc51y',
#  'fb:m.0vp6tvj',
#  'fb:m.0fp_h0x',
#  'fb:m.065yt9g',
#  'fb:m.0crts2b',
#  'fb:m.0ds0msq',
#  'fb:m.01wsb6t',
#  'fb:m.09f2y2',
#  'fb:m.08m6hs',
#  'fb:m.0knt66v',
#  'fb:m.0n4pmbm',
#  'fb:m.02jkh6',
#  'fb:m.0gnd0_',
#  'fb:m.0343fl',
#  'fb:m.04lflcz',
#  'fb:m.0bqp6q',
#  'fb:m.01jb87m',
#  'fb:m.0czqv8',
#  'fb:m.05q9qw7',
#  'fb:m.0n9q66q',
#  'fb:m.027yj3_',
#  'fb:m.06y8jq',
#  'fb:m.0jsszsq',
#  'fb:m.01ppp_',
#  'fb:m.02x5w_t',
#  'fb:m.0nf0gg_',
#  'fb:m.06zprwq',
#  'fb:m.04p9v4',
#  'fb:m.0n9_967',
#  'fb:m.025v4n9',
#  'fb:m.084xdc',
#  'fb:m.0gvsxbj',
#  'fb:m.07kg7t',
#  'fb:m.0jq6f0t',
#  'fb:m.03ccg5x',
#  'fb:m.0jvqrw_',
#  'fb:m.027b7wl',
#  'fb:m.06w5lm_',
#  'fb:m.0bpr3j',
#  'fb:m.09_zf6',
#  'fb:m.06ykpr',
#  'fb:m.01hrbxh',
#  'fb:m.0g7xb6r',
#  'fb:m.0w_j3qc',
#  'fb:m.0bfdybx',
#  'fb:m.05y0gp',
#  'fb:m.027c47_',
#  'fb:m.02jm68',
#  'fb:m.03mn71',
#  'fb:m.03ns4b2',
#  'fb:m.0dnsww',
#  'fb:m.0jvt7r9',
#  'fb:m.04zyll6',
#  'fb:m.0dl__d',
#  'fb:m.0pdkvz6',
#  'fb:m.04ydq6f',
#  'fb:m.04ct3x2',
#  'fb:m.0g5r1mv',
#  'fb:m.0_w68dl',
#  'fb:m.02vtvx9',
#  'fb:m.05q5xv8',
#  'fb:m.02pzfgc',
#  'fb:m.046450',
#  'fb:m.0gyc8sm',
#  'fb:m.0wptkm8',
#  'fb:m.05sy9ss',
#  'fb:m.02qlj0h',
#  'fb:m.0h_d5sd',
#  'fb:m.0k046q9',
#  'fb:m.0yq43s6',
#  'fb:m.02rfnbr',
#  'fb:m.01ldmj',
#  'fb:m.027hcwl',
#  'fb:m.02w906n',
#  'fb:m.0gm2bhf',
#  'fb:m.0qzf39_',
#  'fb:m.0cgj_wk',
#  'fb:m.0cj59k_',
#  'fb:m.0d7_4',
#  'fb:m.05pb754',
#  'fb:m.0wpbp8l',
#  'fb:m.0262_lw',
#  'fb:m.03f0wqk',
#  'fb:m.03y8_z6',
#  'fb:m.0927w6',
#  'fb:m.0g9mdvs',
#  'fb:m.01304j',
#  'fb:m.04phqj',
#  'fb:m.0bvqbrz',
#  'fb:m.03l2cs',
#  'fb:m.03cq383',
#  'fb:m.0nbwwff',
#  'fb:m.0ftx5k',
#  'fb:m.037n_q',
#  'fb:m.0y72ht9',
#  'fb:m.094xxb',
#  'fb:m.0gcylcv',
#  'fb:m.0f81sk',
#  'fb:m.02hblj',
#  'fb:m.086df5',
#  'fb:m.078q2m',
#  'fb:m.02vymwq',
#  'fb:m.0h1d93n',
#  'fb:m.0gccpz7',
#  'fb:m.0gcc__v',
#  'fb:m.04ns4cs',
#  'fb:m.0crjgv_',
#  'fb:m.0pcb2j3',
#  'fb:m.0gmltkj',
#  'fb:m.0gblx7c',
#  'fb:m.0fqskv8',
#  'fb:m.0hnschr',
#  'fb:m.06_39h',
#  'fb:m.0k06k4n',
#  'fb:m.0_vgddq',
#  'fb:m.02rdcby',
#  'fb:m.0r94fpw',
#  'fb:m.02x45g1',
#  'fb:m.01jl45h',
#  'fb:m.0x1lp1r',
#  'fb:m.03chj4n',
#  'fb:m.05c95x',
#  'fb:m.0js_y0',
#  'fb:m.0gvsqks',
#  'fb:m.0g9mf5h',
#  'fb:m.0561rz',
#  'fb:m.0czblvb',
#  'fb:m.05q52qr',
#  'fb:m.03d2vlf',
#  'fb:m.0cxjrp',
#  'fb:m.06rmbl',
#  'fb:m.0gvb9v',
#  'fb:m.03nfh2',
#  'fb:m.0gcp70t',
#  'fb:m.0jvpw11',
#  'fb:m.0ndcft4',
#  'fb:m.0vzh4',
#  'fb:m.0n4qqw1',
#  'fb:m.0k1jnmc',
#  'fb:m.0g5sjb2',
#  'fb:m.03y00bv',
#  'fb:m.0jvh845',
#  'fb:m.02_r5p',
#  'fb:m.0vp3m68',
#  'fb:m.0_r82bj',
#  'fb:m.0k059v8',
#  'fb:m.07s9yzp',
#  'fb:m.08g1wb',
#  'fb:m.05h3lk6',
#  'fb:m.02r0d1j',
#  'fb:m.09g6v42',
#  'fb:m.0h1cs9t',
#  'fb:m.0261xcy',
#  'fb:m.0658zh',
#  'fb:m.086m30',
#  'fb:m.0h45p4',
#  'fb:m.0b6mljj',
#  'fb:m.0z3vlp0',
#  'fb:m.0ctww9',
#  'fb:m.0dr45y',
#  'fb:m.08vwyds',
#  'fb:m.02ygr1',
#  'fb:m.03ym_70',
#  'fb:m.01jr935',
#  'fb:m.07771l',
#  'fb:m.0d0qws',
#  'fb:m.0fy5sc_',
#  'fb:m.0kdnqzx',
#  'fb:m.0ly_5',
#  'fb:m.01l7jvc',
#  'fb:m.0gmdb2_',
#  'fb:m.04120vy',
#  'fb:m.05_60xn',
#  'fb:m.0chtg3x',
#  'fb:m.038mrx',
#  'fb:m.077mdt',
#  'fb:m.02pjg55',
#  'fb:m.0g5s8th',
#  'fb:m.06xsps',
#  'fb:m.03by6tb',
#  'fb:m.02q0fvd',
#  'fb:m.0f6dsfk',
#  'fb:m.03m1dh',
#  'fb:m.03wcr9r',
#  'fb:m.014cg0',
#  'fb:m.09y7rz',
#  'fb:m.08twm0',
#  'fb:m.05bhjn8',
#  'fb:m.06zmgwv',
#  'fb:m.06jp90',
#  'fb:m.02vqmvm',
#  'fb:m.0gxlcb',
#  'fb:m.0qt3tmm',
#  'fb:m.0h4bnw',
#  'fb:m.043lx1y',
#  'fb:m.01jb5mb',
#  'fb:m.047drb0',
#  'fb:m.027nhr6',
#  'fb:m.0b6j1hb',
#  'fb:m.026pc98',
#  'fb:m.01q5mvd',
#  'fb:m.02q0wnp',
#  'fb:m.02v_j__',
#  'fb:m.0vt9lj3',
#  'fb:m.05hpkd',
#  'fb:m.0rmkz',
#  'fb:m.0gwywf6',
#  'fb:m.03c53qc',
#  'fb:m.0gbxvs6',
#  'fb:m.01_8_',
#  'fb:m.0k1hz',
#  'fb:m.02r1pcy',
#  'fb:m.0w2787g',
#  'fb:m.0qpwrxv',
#  'fb:m.0cgqs9g',
#  'fb:m.027pb6m',
#  'fb:m.0fqq2mm',
#  'fb:m.0h4btj',
#  'fb:m.0cz2z9',
#  'fb:m.0yhydj4',
#  'fb:m.03ql8fp',
#  'fb:m.0h7nmsv',
#  'fb:m.05f5p_q',
#  'fb:m.0j6tb_k',
#  'fb:m.0y6464g',
#  'fb:m.0wz_l72',
#  'fb:m.03yfzv1',
#  'fb:m.0627q4',
#  'fb:m.0d1pg1',
#  'fb:m.01s_b29',
#  'fb:m.0bffy6',
#  'fb:m.0gtxlzf',
#  'fb:m.02z299z',
#  'fb:m.02wxxpn',
#  'fb:m.05pf2q',
#  'fb:m.0_qtgql',
#  'fb:m.047k3_v',
#  'fb:m.0dvvny',
#  'fb:m.02w02z7',
#  'fb:m.0vb9n5h',
#  'fb:m.02wbcqp',
#  'fb:m.0vxs8mc',
#  'fb:m.032p24',
#  'fb:m.09c2n2',
#  'fb:m.0zdshf2',
#  'fb:m.0gsyvv0',
#  'fb:m.0v312ww',
#  'fb:m.028b3_5',
#  'fb:m.07844v',
#  'fb:m.05b11zj',
#  'fb:m.03h5n87',
#  'fb:m.0wzvwys',
#  'fb:m.03cyfn6',
#  'fb:m.0n51371',
#  'fb:m.06t59s',
#  'fb:m.04jjkps',
#  'fb:m.02vsrqf',
#  'fb:m.0k773y5',
#  'fb:m.09rhxfg',
#  'fb:m.0xn15lr',
#  'fb:m.0gxlf3',
#  'fb:m.01pjzjn',
#  'fb:m.03c79ky',
#  'fb:m.0dzv7j',
#  'fb:m.0636sw',
#  'fb:m.01hd101',
#  'fb:m.0_ysjw9',
#  'fb:m.02w0zyf',
#  'fb:m.0jxcc_9',
#  'fb:m.026qt7h',
#  'fb:m.02r_7_v',
#  'fb:m.0cvp23',
#  'fb:m.03h0pyq',
#  'fb:m.0d_cvq',
#  'fb:m.0_gfc3v',
#  'fb:m.03yk54c',
#  'fb:m.04fkz0',
#  'fb:m.01rzccv',
#  'fb:m.03bg6v',
#  'fb:m.05zrgv1',
#  'fb:m.025zq7k',
#  'fb:m.0wl3lxz',
#  'fb:m.0zfm6q6',
#  'fb:m.05fcc38',
#  'fb:m.0hcr70y',
#  'fb:m.05b_lys',
#  'fb:m.08tgjz',
#  'fb:m.0fty86',
#  'fb:m.05c273b',
#  'fb:m.043k1rl',
#  'fb:m.0ncxpzt',
#  'fb:m.03nqrl2',
#  'fb:m.080bffz',
#  'fb:m.03243y',
#  'fb:m.0yq110y',
#  'fb:m.0lwnk3l',
#  'fb:m.027pqmh',
#  'fb:m.0jt194v',
#  'fb:m.0ds_dxj',
#  'fb:m.0plw2xm',
#  'fb:m.0jxrpm',
#  'fb:m.01jbt6y',
#  'fb:m.0wy3ltg',
#  'fb:m.02vlr4l',
#  'fb:m.0bvcg22',
#  'fb:m.0n1y3r6',
#  'fb:m.03m85dm',
#  'fb:m.02z4zrd',
#  'fb:m.0_qpvg8',
#  'fb:m.0c4jh0x',
#  'fb:m.0k083g',
#  'fb:m.04fzzbm',
#  'fb:m.0gc3z30',
#  'fb:m.0h7w4th',
#  'fb:m.01rvrn',
#  'fb:m.0j9f_hs',
#  'fb:m.03ch7r9',
#  'fb:m.0mxzgzp',
#  'fb:m.04mncd0',
#  'fb:m.0gvsprn',
#  'fb:m.02vydb0',
#  'fb:m.0rntz4g',
#  'fb:m.0rqjl6b',
#  'fb:m.0_xpzfr',
#  'fb:m.0hn82ph',
#  'fb:m.054wb66',
#  'fb:m.026jpyz',
#  'fb:m.0b3wt07',
#  'fb:m.03gxx87',
#  'fb:m.0gbwvkw',
#  'fb:m.0brqcq',
#  'fb:m.09gfhjt',
#  'fb:m.0848z2',
#  'fb:m.03vgbf',
#  'fb:m.0pccxk6',
#  'fb:m.03nwy6b',
#  'fb:m.04455p',
#  'fb:m.0yn93g9',
#  'fb:m.0n9ww0g',
#  'fb:m.082l9t',
#  'fb:m.03c4x2b',
#  'fb:m.05v9gyy',
#  'fb:m.05c1sd3',
#  'fb:m.063_4t8',
#  'fb:m.0d8f2w',
#  'fb:m.0bqsdrs',
#  'fb:m.091rks',
#  'fb:m.03m6q3v',
#  'fb:m.02x5rzh',
#  'fb:m.080k_x',
#  'fb:m.071t45',
#  'fb:m.0x1j8q8',
#  'fb:m.0k3d82x',
#  'fb:m.088109',
#  'fb:m.03cn02',
#  'fb:m.0g4p35m',
#  'fb:m.0ckvsk',
#  'fb:m.0bs36g5',
#  'fb:m.03c4n1d',
#  'fb:m.0bv9ts9',
#  'fb:m.02pysml',
#  'fb:m.085zq8',
#  'fb:m.03cl3fp',
#  'fb:m.0cmq6y',
#  'fb:m.04g15tj',
#  'fb:m.0v25mkm',
#  'fb:m.0bgg1zs',
#  'fb:m.03yd_l',
#  'fb:m.01dtnl',
#  'fb:m.04y9r88',
#  'fb:m.0_rfy8m',
#  'fb:m.02w9wzq',
#  'fb:m.03wfk35',
#  'fb:m.02yz98',
#  'fb:m.0ds13p',
#  'fb:m.0j8q0xx',
#  'fb:m.03cgjpj',
#  'fb:m.02q599h',
#  'fb:m.0gy5qz',
#  'fb:m.01mm31d',
#  'fb:m.0k4ht7',
#  'fb:m.02w8_8r',
#  'fb:m.0ngk659',
#  'fb:m.0y47qnw',
#  'fb:m.0fylzf',
#  'fb:m.0266kb4',
#  'fb:m.03hn2y0',
#  'fb:m.0gc3bnc',
#  'fb:m.05j_lm',
#  'fb:m.04mw1gx',
#  'fb:m.0bbv5cj',
#  'fb:m.0465qkn',
#  'fb:m.0h2m976',
#  'fb:m.094sw8',
#  'fb:m.02wbcb9',
#  'fb:m.0j50_j0',
#  'fb:m.0xn60vq',
#  'fb:m.05h42dm',
#  'fb:m.0hgdd2j',
#  'fb:m.05p5nbk',
#  'fb:m.0btlt1',
#  'fb:m.0gpfk5',
#  'fb:m.04f2x70',
#  'fb:m.026450b',
#  'fb:m.0gchqt_',
#  'fb:m.04ghc43',
#  'fb:m.04n6bv0',
#  'fb:m.0dbj4q',
#  'fb:m.0crw6q5',
#  'fb:m.0bffn0',
#  'fb:m.0ks9w4',
#  'fb:m.0bfbmt3',
#  'fb:m.02x34df',
#  'fb:m.01hhd7',
#  'fb:m.06w3mp2',
#  'fb:m.02w7kw2',
#  'fb:m.0gfhzpv',
#  'fb:m.04q2hjd',
#  'fb:m.08_ps4',
#  'fb:m.04nrtvt',
#  'fb:m.09hn9l',
#  'fb:m.027z_cw',
#  'fb:m.0vs7lks',
#  'fb:m.0nbv4p9',
#  'fb:m.02x3z6j',
#  'fb:m.06y8r9',
#  'fb:m.0j50vsf',
#  'fb:m.03c13k_',
#  'fb:m.0glpqv9',
#  'fb:m.0gybjgv',
#  'fb:m.012y7x',
#  'fb:m.0dndvm1',
#  'fb:m.05whqhh',
#  'fb:m.0dgptfg',
#  'fb:m.0fq3vrw',
#  'fb:m.01qvknb',
#  'fb:m.0rf67jw',
#  'fb:m.05p0_7h',
#  'fb:m.0cl3xhl',
#  'fb:m.0g509z',
#  'fb:m.0cpm3yc',
#  'fb:m.0gpnwj',
#  'fb:m.03h1s50',
#  'fb:m.01rvcq6',
#  'fb:m.02vq__5',
#  'fb:m.04y6nzy',
#  'fb:m.027cm5j',
#  'fb:m.0cvd484',
#  'fb:m.0cj3c_b',
#  'fb:m.035nrp',
#  'fb:m.0_qpxyl',
#  'fb:m.0bbzn1g',
#  'fb:m.0zcyt98',
#  'fb:m.03y9qt3',
#  'fb:m.0479f2n',
#  'fb:m.01vrpnp',
#  'fb:m.09twmc',
#  'fb:m.02_4qt_',
#  'fb:m.04y9s0r',
#  'fb:m.02vwkc4',
#  'fb:m.05zzzws',
#  'fb:m.080ffsc',
#  'fb:m.0g5k_bm',
#  'fb:m.0g5l_f_',
#  'fb:m.01mbf9d',
#  'fb:m.04wr31',
#  'fb:m.0ggb1nt',
#  'fb:m.09v2_d0',
#  'fb:m.0gfp9dn',
#  'fb:m.0bdtb93',
#  'fb:m.03qmg1_',
#  'fb:m.0h6shc',
#  'fb:m.02rr1db',
#  'fb:m.0tlb5w9',
#  'fb:m.03d64m6',
#  'fb:m.0k24l3',
#  'fb:m.0vsf_fk',
#  'fb:m.0bgbq8b',
#  'fb:m.01l7jcq',
#  'fb:m.04ghf50',
#  'fb:m.0h7r05w',
#  'fb:m.0bdqvp',
#  'fb:m.064nszv',
#  'fb:m.02ntqk',
#  'fb:m.0_qt31z',
#  'fb:m.04jl6l2',
#  'fb:m.09dyl2g',
#  'fb:m.0dgpry8',
#  'fb:m.0djn17',
#  'fb:m.01hd889',
#  'fb:m.0gdmscv',
#  'fb:m.0wzlhnv',
#  'fb:m.032gnz',
#  'fb:m.0gyb330',
#  'fb:m.03cc6vt',
#  'fb:m.03b443',
#  'fb:m.0j67cl4',
#  'fb:m.0k8qzvt',
#  'fb:m.0j2mztq',
#  'fb:m.0t5pcd5',
#  'fb:m.0d9_by',
#  'fb:m.0b776_q',
#  'fb:m.0n535c_',
#  'fb:m.0clv8mf',
#  'fb:m.0164bwm',
#  'fb:m.0873mf',
#  'fb:m.0z663jg',
#  'fb:m.05zw18_',
#  'fb:m.05zmgk1',
#  'fb:m.0bpj7sh',
#  'fb:m.0dgpc72',
#  'fb:m.0wqjzc3',
#  'fb:m.06zlw0c',
#  'fb:m.0vpl7qs',
#  'fb:m.0crfnt0',
#  'fb:m.0cfttp',
#  'fb:m.02pxv5y',
#  'fb:m.0d_2kv',
#  'fb:m.047m_yd',
#  'fb:m.0dfyj60',
#  'fb:m.076ybd',
#  'fb:m.0405pz0',
#  'fb:m.07kb10v',
#  'fb:m.08nl0z',
#  'fb:m.063yclj',
#  'fb:m.0ypyl2t',
#  'fb:m.03jh9sm',
#  'fb:m.0gdkzxv',
#  'fb:m.0j3z63c',
#  'fb:m.0h2z4c',
#  'fb:m.0dbgcd',
#  'fb:m.09k6g_2',
#  'fb:m.0h7mvt9',
#  'fb:m.0ngvvcm',
#  'fb:m.0d2q5m',
#  'fb:m.0wpw0qq',
#  'fb:m.0byy2sw',
#  'fb:m.0_80h8',
#  'fb:m.05xyhcb',
#  'fb:m.02qwfvw',
#  'fb:m.026q9d9',
#  'fb:m.0b6hz_3',
#  'fb:m.0jwps9',
#  'fb:m.0gc9ctw',
#  'fb:m.0j_y7tq',
#  'fb:m.06krlp',
#  'fb:m.0_yw3rf',
#  'fb:m.0293001',
#  'fb:m.043py4r',
#  'fb:m.03cblzx',
#  'fb:m.02w00yl',
#  'fb:m.0f9kcxr',
#  'fb:m.0c1hd8k',
#  'fb:m.0dljyh8',
#  'fb:m.0jz5n87',
#  'fb:m.052kdk',
#  'fb:m.09ry6k',
#  'fb:m.0523c7l',
#  'fb:m.0hp7sgx',
#  'fb:m.09g50',
#  'fb:m.0bf11l4',
#  'fb:m.0w33rj6',
#  'fb:m.07d8gc',
#  'fb:m.0zcsh6s',
#  'fb:m.036swx',
#  'fb:m.06w69d0',
#  'fb:m.0vv58b7',
#  'fb:m.0gb_p65',
#  'fb:m.038qf8r',
#  'fb:m.0hnph1g',
#  'fb:m.06t8gp',
#  'fb:m.016883',
#  'fb:m.02wb41k',
#  'fb:m.027vhb2',
#  'fb:m.05b5hm6',
#  'fb:m.08bg4z',
#  'fb:m.02pkrzn',
#  'fb:m.0676v6',
#  'fb:m.0bxzcqv',
#  'fb:m.0yf_12k',
#  'fb:m.0ksvtcp',
#  'fb:m.0dd9xd7',
#  'fb:m.03y6g72',
#  'fb:m.0cc6pq8',
#  'fb:m.0qgqxh_',
#  'fb:m.04_8dby',
#  'fb:m.0vt3qcx',
#  'fb:m.0fmp75',
#  'fb:m.0cgzktk',
#  'fb:m.04cllbg',
#  'fb:m.0k3r575',
#  'fb:m.0hgx0fh',
#  'fb:m.02v_yzb',
#  'fb:m.0bb5gkg',
#  'fb:m.09dw3_c',
#  'fb:m.04n5pq3',
#  'fb:m.09gh_j_',
#  'fb:m.0wylmyh',
#  'fb:m.018c54',
#  'fb:m.0ndskzd',
#  'fb:m.0j54g4r',
#  'fb:m.0p79wf8',
#  'fb:m.0k78822',
#  'fb:m.025ywlv',
#  'fb:m.0n9l2w1',
#  'fb:m.0gfrl81',
#  'fb:m.02q9_m4',
#  'fb:m.0287ky',
#  'fb:m.0ytg845',
#  'fb:m.05q53lv',
#  'fb:m.0gjf1hn',
#  'fb:m.03yz63p',
#  'fb:m.08hm3f',
#  'fb:m.03d11rd',
#  'fb:m.02rtbz5',
#  'fb:m.0tk4sr2',
#  'fb:m.0yqh5ll',
#  'fb:m.09gcszr',
#  'fb:m.0r9szp5',
#  'fb:m.0j3z8g7',
#  'fb:m.0bvrqsy',
#  'fb:m.0cs54g0',
#  'fb:m.02qfcy0',
#  'fb:m.03cqhkm',
#  'fb:m.02rknjj',
#  'fb:m.02r188p',
#  'fb:m.08751_',
#  'fb:m.0h53d4p',
#  'fb:m.027k0vd',
#  'fb:m.0w6twq6',
#  'fb:m.05zlws8',
#  'fb:m.0_g4z6s',
#  'fb:m.02plytt',
#  'fb:m.01q2k4x',
#  'fb:m.08077t3',
#  'fb:m.0bdtwg',
#  'fb:m.0v_q5y1',
#  'fb:m.0kvygcw',
#  'fb:m.0gyvwqh',
#  'fb:m.024kx8',
#  'fb:m.077p_2',
#  'fb:m.0v__st8',
#  'fb:m.01qgq0z',
#  'fb:m.050vqm',
#  'fb:m.0pkzgwf',
#  'fb:m.0gcbw7y',
#  'fb:m.047s6kn',
#  'fb:m.0b14bb',
#  'fb:m.0fpx0r',
#  'fb:m.0288pnl',
#  'fb:m.093kw5',
#  'fb:m.0f48st',
#  'fb:m.0fpp9nr',
#  'fb:m.0s9k0w4',
#  'fb:m.03d0vw8',
#  'fb:m.047rryn',
#  'fb:m.028b229',
#  'fb:m.0zhmsgb',
#  'fb:m.0bk79b',
#  'fb:m.06ykp1',
#  'fb:m.0805wbf',
#  'fb:m.07bnsk',
#  'fb:m.0jyd8s',
#  'fb:m.02vwtc7',
#  'fb:m.0420x7r',
#  'fb:m.0gdkpcb',
#  'fb:m.0dz11j',
#  'fb:m.0gc84gc',
#  'fb:m.0h2_3_7',
#  'fb:m.043l3wr',
#  'fb:m.02rgvb0',
#  'fb:m.0921x2',
#  'fb:m.0g5r44s',
#  'fb:m.043pxz',
#  'fb:m.04_70f1',
#  'fb:m.0gvhnmw',
#  'fb:m.0bvsnmb',
#  'fb:m.06zqwfj',
#  'fb:m.0411vqn',
#  'fb:m.01wy24k',
#  'fb:m.056698',
#  'fb:m.0bwkh5g',
#  'fb:m.0_bn8y4',
#  'fb:m.0w_l4mv',
#  'fb:m.0hnbw8t',
#  'fb:m.02xv2t',
#  'fb:m.06x9qp',
#  'fb:m.040bwh',
#  'fb:m.0jvtqgn',
#  'fb:m.05wl2py',
#  'fb:m.0gmlv1g',
#  'fb:m.0x0xpzg',
#  'fb:m.0y4t4wr',
#  'fb:m.01g6nlc',
#  'fb:m.06_y3kg',
#  'fb:m.0wp9fmq',
#  'fb:m.0hp96',
#  'fb:m.0b71j2',
#  'fb:m.0j3wvsc',
#  'fb:m.061tsc',
#  'fb:m.0c819j',
#  'fb:m.0n5wz74',
#  'fb:m.0r4r3pk',
#  'fb:m.0mv9jzs',
#  'fb:m.01wm909',
#  'fb:m.0cp0m7x',
#  'fb:m.09v6mdc',
#  'fb:m.03c9k73',
#  'fb:m.0cmc07w',
#  'fb:m.0gc4bxl',
#  'fb:m.087g7q',
#  'fb:m.06pctwm',
#  'fb:m.0bbxwws',
#  'fb:m.09k81c_',
#  'fb:m.0gcxjg0',
#  'fb:m.0gb_2s1',
#  'fb:m.02810z6',
#  'fb:m.0j7nh3p',
#  'fb:m.02r5t9d',
#  'fb:m.0dm3hx1',
#  'fb:m.02h_3b',
#  'fb:m.0h16fwh',
#  'fb:m.0ks7xv',
#  'fb:m.04brs0',
#  'fb:m.0lwvrqz',
#  'fb:m.03cl496',
#  'fb:m.015dsz',
#  'fb:m.0h4nk49',
#  'fb:m.0hzrbzc',
#  'fb:m.0cqksk',
#  'fb:m.0h8dw9c',
#  'fb:m.03m79mr',
#  'fb:m.0jvjz_s',
#  'fb:m.03m5wnd',
#  'fb:m.0j676w7',
#  'fb:m.0y61k64',
#  'fb:m.03m6grn',
#  'fb:m.03cmfl5',
#  'fb:m.0qgr824',
#  'fb:m.05hdhj',
#  'fb:m.0crv7xt',
#  'fb:m.0qpydgt',
#  'fb:m.03f7k3v',
#  'fb:m.0bgrkp',
#  'fb:m.026j2gs',
#  'fb:m.02pnw5b',
#  'fb:m.0j27x_c',
#  'fb:m.01vwdq',
#  'fb:m.0c624p',
#  'fb:m.080jwlx',
#  'fb:m.02_qfv',
#  'fb:m.0vtt9j2',
#  'fb:m.013rdf',
#  'fb:m.09zx9p0',
#  'fb:m.03h4js4',
#  'fb:m.02rzl4s',
#  'fb:m.04308z9',
#  'fb:m.0bmfyw9',
#  'fb:m.0279681',
#  'fb:m.01p8h_q',
#  'fb:m.0j9bf5l',
#  'fb:m.0275lwp',
#  'fb:m.03wh5v1',
#  'fb:m.07kdjv3',
#  'fb:m.0g4jf61',
#  'fb:m.0ndst8p',
#  'fb:m.0gmcc9',
#  'fb:m.07vqqcd',
#  'fb:m.0bhgxc8',
#  'fb:m.04_5lqt',
#  'fb:m.0clbgg',
#  'fb:m.09c29r',
#  'fb:m.03yf5g',
#  'fb:m.03ck650',
#  'fb:m.06w979p',
#  'fb:m.06tk78',
#  'fb:m.0v1b397',
#  'fb:m.0xj1rv1',
#  'fb:m.0ktdrf',
#  'fb:m.09gqd5q',
#  'fb:m.01n04q_',
#  'fb:m.0mx66gv',
#  'fb:m.02vs2xx',
#  'fb:m.04q6qbv',
#  'fb:m.02wbkxp',
#  'fb:m.0d43wk',
#  'fb:m.09rt29l',
#  'fb:m.03nvs57',
#  'fb:m.0j8fv7n',
#  'fb:m.0b_4ssb',
#  'fb:m.06zp5hg',
#  'fb:m.04gtszw',
#  'fb:m.06zlmz5',
#  'fb:m.02w1tdb',
#  'fb:m.01scmm0',
#  'fb:m.0bm0s7',
#  'fb:m.03f3001',
#  'fb:m.05778bg',
#  'fb:m.0j2lrh0',
#  'fb:m.0n186c2',
#  'fb:m.028606x',
#  'fb:m.094g0r',
#  'fb:m.03d8md6',
#  'fb:m.0q3mpqr',
#  'fb:m.0g8_kc1',
#  'fb:m.0gdlcfc',
#  'fb:m.026979f',
#  'fb:m.015lhm',
#  'fb:m.0ymfdw0',
#  'fb:m.0h1xqy1',
#  'fb:m.0bq9t12',
#  'fb:m.03cggsq',
#  'fb:m.0p7gnx9',
#  'fb:m.0whftzz',
#  'fb:m.02w3l0h',
#  'fb:m.0x107q3',
#  'fb:m.0bxl72g',
#  'fb:m.0xnc7jd',
#  'fb:m.0ds8brs',
#  'fb:m.0n918tt',
#  'fb:m.026_fsn',
#  'fb:m.0cb615',
#  'fb:m.0kj5f4d',
#  'fb:m.02bfyx',
#  'fb:m.07s9h6b',
#  'fb:m.06zjnrq',
#  'fb:m.0gk_36b',
#  'fb:m.03mf4z8',
#  'fb:m.020xxr',
#  'fb:m.03m64hr',
#  'fb:m.0pz0syf',
#  'fb:m.03h1fn5',
#  'fb:m.0qj7r4l',
#  'fb:m.05rv8p',
#  'fb:m.032szkw',
#  'fb:m.06wb5q7',
#  'fb:m.0806lbm',
#  'fb:m.01jb7k2',
#  'fb:m.02885fj',
#  'fb:m.0n1_8vv',
#  'fb:m.0cgzjxv',
#  'fb:m.0g1x4w',
#  'fb:m.01w43dp',
#  'fb:m.047ldr8',
#  'fb:m.0p7g6yq',
#  'fb:m.0n3j_cq',
#  'fb:m.0t5t77c',
#  'fb:m.0crrrtd',
#  ...}

# %%
# explore
lineid = 'valid-1'
question = id2question[lineid]
print(question)
cand_relations = id2rel[lineid]
print(cand_relations)
query_text = id2query[lineid].lower()  # lowercase the query
print(query_text)
query_tokens = tokenize_text(query_text)
print(query_tokens)
N = min(len(query_tokens), 3)
print(N)
# Out:
# ('fb:m.0f3xg_', 'fb:symbols.namesake.named_after', 'Who was the trump ocean club international hotel and tower named after')
# [('fb:symbols.namesake.named_after', '1', '-0.9163265228271484'), ('fb:protected_sites.protected_site.governing_body', '0', '-2.0246400833129883'), ('fb:sports.professional_sports_team.owner_s', '0', '-2.1866111755371094')]
# trump ocean club international hotel and tower
# ['trump', 'ocean', 'club', 'international', 'hotel', 'and', 'tower']
# 3

# %%
C = []  # candidate entities
for n in range(N, 0, -1):
    ngrams_set = find_ngrams(query_tokens, n)
    print("ngrams_set: {}".format(ngrams_set))
    for ngram_tuple in ngrams_set:
        ngram = " ".join(ngram_tuple)
        ngram = strip_accents(ngram)
        # unigram stopwords have too many candidates so just skip over
        if ngram in stopwords:
            continue
        print("ngram: {}".format(ngram))
        ## PROBLEM! - ngram doesnt exist in index - at test-2592 - KeyError: 'p.a.r.c.e. parce'
        try:
            cand_mids = index_ent[ngram]  # search entities
        except:
            continue
        C.extend(cand_mids)
        # print("C: {}".format(C))
    if (len(C) > 0):
        print("early termination...")
        break
    break
print(C)
# Out:
# ngrams_set: {('hotel', 'and', 'tower'), ('trump', 'ocean', 'club'), ('international', 'hotel', 'and'), ('ocean', 'club', 'international'), ('club', 'international', 'hotel')}
# ngram: hotel and tower
# ngram: trump ocean club
# ngram: international hotel and
# ngram: ocean club international
# ngram: club international hotel
# early termination...
# ['fb:m.07dwg4', 'fb:m.031n7n', 'fb:m.08cbdd', 'fb:m.05d9c4', 'fb:m.0f3xg_', 'fb:m.0f3xg_', 'fb:m.07dwg4', 'fb:m.031n7n', 'fb:m.08cbdd', 'fb:m.05d9c4', 'fb:m.0f3xg_', 'fb:m.0f3xg_', 'fb:m.0f3xg_']

# %%
C_pruned = []
for mid in set(C):
    if mid in index_reach.keys():  # PROBLEM: don't know why this may not exist??
        count_mid = C.count(mid)  # count number of times mid appeared in C
        C_pruned.append((mid, count_mid))

print(C_pruned)
# Out:
# [('fb:m.07dwg4', 2), ('fb:m.031n7n', 2), ('fb:m.08cbdd', 2), ('fb:m.05d9c4', 2), ('fb:m.0f3xg_', 5)]

# %%
C_tfidf_pruned = []
for mid, count_mid in C_pruned:
    if mid in index_names.keys():
        cand_ent_name = pick_best_name(question[2], index_names[mid])
        tfidf = calc_tf_idf(query_text, cand_ent_name, count_mid, num_entities_fbsubset, index_ent)
        C_tfidf_pruned.append((mid, cand_ent_name, tfidf))
# print("C_tfidf_pruned[:10]: {}".format(C_tfidf_pruned[:10]))
print(C_tfidf_pruned)

C_tfidf_pruned.sort(key=lambda t: -t[2])

cand_mids = C_tfidf_pruned[:3]
print(cand_mids)
# Out:
# [('fb:m.01137v', 'barneveld , wisconsin', 0.0), ('fb:m.0ltkqjt', 'iowa', 0.9026471189213551), ('fb:m.0t2f3', 'ankeny , iowa', 0.9026471189213551), ('fb:m.0t08t', 'hedrick , iowa', 0.9026471189213551), ('fb:m.048y6w0', 'five seasons mobile home park', 0.0), ('fb:m.048y68v', 'lore mobile home park', 0.0), ('fb:m.048y60v', 'kammerer trailer court , iowa', 0.9026471189213551), ('fb:m.0st2v', 'new hampton , iowa', 0.9026471189213551), ('fb:m.0szbf', 'fayette , iowa', 0.9026471189213551), ('fb:m.048yy_v', 'paris , iowa', 0.9026471189213551), ('fb:m.0t3fv', 'roland , iowa', 0.9026471189213551), ('fb:m.02pq5z7', 'buckingham , iowa', 0.9026471189213551), ('fb:m.048yhd8', 'paralta , iowa', 0.9026471189213551), ('fb:m.0s_xq', 'oakland acres , iowa', 0.9026471189213551), ('fb:m.0t2wk', 'lake view , iowa', 0.9026471189213551), ('fb:m.048y8_s', 'bridgeport , iowa', 0.9026471189213551), ('fb:m.0t3mb', 'vining , iowa', 0.9026471189213551), ('fb:m.0t1np', 'soldier , iowa', 0.9026471189213551), ('fb:m.0stsw', 'dallas center , iowa', 0.9026471189213551), ('fb:m.0t2hj', 'saylorville , iowa', 0.9026471189213551), ('fb:m.0t4pr', 'salix , iowa', 0.9026471189213551), ('fb:m.03gszpk', 'brighton township', 0.0), ('fb:m.0dd56z', 'quad cities international raceway park', 0.0), ('fb:m.0ssmy', 'anita , iowa', 0.9026471189213551), ('fb:m.0sstf', 'wilton , iowa', 0.9026471189213551), ('fb:m.048yc23', 'fernald , iowa', 0.9026471189213551), ('fb:m.04120v7', 'grant township , story county , iowa', 0.9026471189213551), ('fb:m.0ssv4', 'dougherty , iowa', 0.9026471189213551), ('fb:m.0t1cm', 'marshalltown , iowa', 0.9026471189213551), ('fb:m.048ym0m', 'mason city junction', 0.0), ('fb:m.048yxhv', 'twin springs , iowa', 0.9026471189213551), ('fb:m.06_9t7p', 'letovsky-rohret house , iowa city', 0.9026471189213551), ('fb:m.0ssvh', 'mason city , iowa', 0.9026471189213551), ('fb:m.0stgj', 'volga , iowa', 0.9026471189213551), ('fb:m.0nt_mcy', 'iowa', 0.9026471189213551), ('fb:m.0sr7w', 'bridgewater', 0.0), ('fb:m.0111pp', 'highland , douglas county , wisconsin', 0.0), ('fb:m.0t2_0', 'donahue , iowa', 0.9026471189213551), ('fb:m.0t0yj', 'russell , iowa', 0.9026471189213551), ('fb:m.01y07b', 'iowa cubs', 0.9026471189213551), ('fb:m.048y4n8', 'sycamore village', 0.0), ('fb:m.0st8b', 'clayton , iowa', 0.9026471189213551), ('fb:m.03gtf3m', 'grant township , cerro gordo county , iowa', 0.9026471189213551), ('fb:m.0t45x', 'allerton , iowa', 0.9026471189213551), ('fb:m.0t05c', 'monticello , iowa', 0.9026471189213551), ('fb:m.0ss8l', 'aredale , iowa', 0.9026471189213551), ('fb:m.048y77h', 'hometown-cedar terrace , iowa', 0.9026471189213551), ('fb:m.048yqh6', 'diamond , iowa', 0.9026471189213551), ('fb:m.0ssh3', 'yetter , iowa', 0.9026471189213551), ('fb:m.03gszp6', 'benton township', 0.0), ('fb:m.0m604l0', 'iowa', 0.9026471189213551), ('fb:m.0t2r2', 'searsboro , iowa', 0.9026471189213551), ('fb:m.0sv8q', 'dickinson county / lake park city', 0.0), ('fb:m.0t1qd', 'lovilia , iowa', 0.9026471189213551), ('fb:m.048yxh7', 'twin springs , iowa', 0.9026471189213551), ('fb:m.0sz_2', 'webster city , iowa', 0.9026471189213551), ('fb:m.048yq48', 'veo , iowa', 0.9026471189213551), ('fb:m.048yjk4', 'sawyer , iowa', 0.9026471189213551), ('fb:m.048ywml', 'rogers , iowa', 0.9026471189213551), ('fb:m.0std3', 'mcgregor , iowa', 0.9026471189213551), ('fb:m.0wg6bc1', 'iowa', 0.9026471189213551), ('fb:m.0t489', 'seymour , iowa', 0.9026471189213551), ('fb:m.0g8r1tr', 'iowa', 0.9026471189213551), ('fb:m.0rktgwt', 'iowa state university', 0.9026471189213551), ('fb:m.048y4vr', 'lamson mobile home park', 0.0), ('fb:m.048y7yl', 'abingdon , iowa', 0.9026471189213551), ('fb:m.048y4vc', 'spring creek village mobile home park , iowa', 0.9026471189213551), ('fb:m.03gsztb', 'pleasant township , cass county , iowa', 0.9026471189213551), ('fb:m.0t2bq', 'palmer , iowa', 0.9026471189213551), ('fb:m.02vkl47', 'secretary of state of iowa', 0.9026471189213551), ('fb:m.0zkwx1z', 'iowa', 0.9026471189213551), ('fb:m.0t06r' ...
# [('fb:m.0ltkqjt', 'iowa', 0.9026471189213551), ('fb:m.0t2f3', 'ankeny , iowa', 0.9026471189213551), ('fb:m.0t08t', 'hedrick , iowa', 0.9026471189213551)]

# %%
def fuzzy_match_score(name, question):
    score =  fuzz.ratio(name, question) / 100.0
    return score

# %%
notfound_ent = 0
notfound_c = 0
notfound_c_lineids = []
notfound_ent = 0
notcorrect_ent_lineids = []
candidate_mids = {}
HITS_TOP_ENTITIES = 5

for i, lineid in enumerate(rel_lineids):
    if lineid not in ent_lineids:
        notfound_ent += 1
        continue
        
    if (i+1) % 100 == 0:
        print()
    
    question = id2question[lineid]
    query_text = id2query[lineid].lower()  # lowercase the query
    query_tokens = tokenize_text(query_text)

    # print("lineid: {}, query_text: {}, relation: {}".format(lineid, query_text, pred_relation))
    # print("query_tokens: {}".format(query_tokens))

    N = min(len(query_tokens), 3)
    C = []  # candidate entities
    for n in range(N, 0, -1):
        ngrams_set = find_ngrams(query_tokens, n)
        # print("ngrams_set: {}".format(ngrams_set))
        for ngram_tuple in ngrams_set:
            ngram = " ".join(ngram_tuple)
            ngram = strip_accents(ngram)
            # unigram stopwords have too many candidates so just skip over
            if ngram in stopwords:
                continue
            # print("ngram: {}".format(ngram))
            try:
                cand_mids = index_ent[ngram]  # search entities
            except:
                continue
            C.extend(cand_mids)
            # print("C: {}".format(C))
        if (len(C) > 0):
            # print("early termination...")
            break
    # print("C[:5]: {}".format(C[:5]))

    # relation correction
    C_pruned = []
    for mid in set(C):
        if mid in index_reach.keys():  # PROBLEM: don't know why this may not exist??
            count_mid = C.count(mid)  # count number of times mid appeared in C
            C_pruned.append((mid, count_mid))

    C_tfidf_pruned = []
    for mid, count_mid in C_pruned:
        if mid in index_names.keys():
            cand_ent_name = pick_best_name(question[2], index_names[mid])
#             score = calc_tf_idf(query_text, cand_ent_name, count_mid, num_entities_fbsubset, index_ent)
            score = fuzzy_match_score(cand_ent_name, query_text)
            C_tfidf_pruned.append((mid, cand_ent_name, score))
    # print("C_tfidf_pruned[:10]: {}".format(C_tfidf_pruned[:10]))

    if len(C_tfidf_pruned) == 0:
        #print("WARNING: C_tfidf_pruned is empty.")
        notfound_c_lineids.append(lineid)
        notfound_c += 1
        continue

    C_tfidf_pruned.sort(key=lambda t: -t[2])
    cand_mids = C_tfidf_pruned[:HITS_TOP_ENTITIES]

    candidate_mids[lineid] = cand_mids
#     print(question)
#     print(cand_mids)
#     print("-" * 40)
#     if (i+1) % 3 == 0:
#         break

# %%
candidate_mids['valid-3']

# %%
notfound_c_lineids = ['test-40', 'test-146', 'test-312', 'test-414', 'test-578', 'test-742', 'test-848']
df = []
pred_rel_fault = 0
names_fault = 0
other_fault = 0
names = ['question', 'gold_entity_id', 'gold_entity_name', 'gold_relation', 'query_text', 'predicted_relation']
for lineid in notfound_c_lineids[:50]:
    ent, rel, question = id2question[lineid]
    pred_relation = www2fb(id2rel[lineid])
    query_text = id2query[lineid].lower()  # lowercase the query
#     pred_ent_mid = id2pred_ent[lineid]
    if not pred_relation == rel:
        pred_rel_fault += 1
    else:
        other_fault += 1
    if ent in index_names.keys():
        row = [question, ent, pick_best_name(question, index_names[ent]), rel, query_text, pred_relation]
    else:
        names_fault += 1
    df.append(row)

df = pd.DataFrame(df)
df.columns = names

print(pred_rel_fault)
print(names_fault)
print(other_fault)
# Out:
# 3
# 0
# 4

# %%
df
# Out:
#                                             question gold_entity_id  \
# 0        Which label is somevelvetsidewalk signed to   fb:m.01pm4nb
# 1        what is a short-lived British sitcom series     fb:m.0c4xc
# 2  Who is the focus of uttar pradesh has more tha...   fb:m.0j2hj_0
# 3                    what genre of music is locd out   fb:m.01rrs9n
# 4                     what is cassiesteele's gender?    fb:m.03_fby
# 5                  what is the genre of gusgofficial   fb:m.03f3bp7
# 6  What is the title of the netlix film in the ge...     fb:m.03_3d
#
#                            gold_entity_name  \
# 0                      some velvet sidewalk
# 1                          situation comedy
# 2  uttar pradesh has more than one capital.
# 3                                loc 'd out
# 4                             cassie steele
# 5                      kostas karamitroudis
# 6                    land of the rising sun
#
#                           gold_relation          query_text  \
# 0                 fb:music.artist.label  somevelvetsidewalk
# 1               fb:tv.tv_genre.programs         short-lived
# 2      fb:base.uncommon.exception.focus                than
# 3                  fb:music.album.genre            locd out
# 4               fb:people.person.gender        cassiesteele
# 5                 fb:music.artist.genre        gusgofficial
# 6  fb:media_common.netflix_genre.titles              netlix
#
#                             predicted_relation
# 0                        fb:music.artist.label
# 1                      fb:tv.tv_genre.programs
# 2  fb:base.culturalevent.event.entity_involved
# 3                         fb:music.album.genre
# 4                      fb:people.person.gender
# 5                         fb:music.album.genre
# 6       fb:film.film_genre.films_in_this_genre

# %%
notcorrect_ent_lineids = ['test-2', 'test-6', 'test-7', 'test-8', 'test-11', 'test-12', 'test-15', 'test-18', 'test-19', 'test-20', 'test-22', 'test-23', 'test-24', 'test-25', 'test-26', 'test-27', 'test-29', 'test-30', 'test-31', 'test-32', 'test-39', 'test-41', 'test-43', 'test-45', 'test-47', 'test-48', 'test-49', 'test-50', 'test-52', 'test-61', 'test-65', 'test-66', 'test-67', 'test-68', 'test-69', 'test-71', 'test-73', 'test-75', 'test-76', 'test-77', 'test-78', 'test-79', 'test-81', 'test-82', 'test-85', 'test-87', 'test-88', 'test-91', 'test-92', 'test-93', 'test-94', 'test-95', 'test-96', 'test-97', 'test-98', 'test-100', 'test-104', 'test-105', 'test-110', 'test-112', 'test-113', 'test-118', 'test-125', 'test-127', 'test-128']

df = []
pred_rel_fault = 0
names_fault = 0
other_fault = 0
names = ['question', 'gold_ent_name', 'query_text', 'predicted_ent_name']
for lineid in notcorrect_ent_lineids[:50]:
    ent, rel, question = id2question[lineid]
    pred_relation = www2fb(id2rel[lineid])
    query_text = id2query[lineid].lower()  # lowercase the query
    pred_ent_mid = id2pred_ent[lineid]
    if not pred_relation == rel:
        pred_rel_fault += 1
    else:
        other_fault += 1
    if ent in index_names.keys():
        row = [question, pick_best_name(question,index_names[ent]), query_text,  pick_best_name(question,index_names[pred_ent_mid])]
    else:
        names_fault += 1
    df.append(row)

df = pd.DataFrame(df)
df.columns = names

print(pred_rel_fault)
print(names_fault)
print(other_fault)
# Out:
# 13
# 1
# 37

# %%
df
# Out:
#                                              question  \
# 0                             what format is fearless
# 1           what was the cause of death of yves klein
# 2                Which equestrian was born in dublin?
# 3                           What is a tv action show?
# 4                          What's a song by jean grae
# 5               What position does carlos gomez play?
# 6                  What's a release on pretty in pink
# 7                   Who created the typeface chicago?
# 8   what position does pee wee reese play in baseball
# 9              which artist recorded one life to live
# 10                       what is a track on carpenter
# 11  Which Swiss conductor's cause of death is myoc...
# 12          what type of music does david ruffin play
# 13     what tracks are listed in the release equator?
# 14   What is the track los angeles is a recording of?
# 15                                Name a history film
# 16                          what language is viper in
# 17  what's the name of an environmental disaster i...
# 18           Where was magical mystery tour released?
# 19                   Who influenced michael mcdowell?
# 20         what is the content type of voodoo lounge?
# 21                         which group recorded tokyo
# 22                         who is the creator of loud
# 23        What is the name of a western (genre) film?
# 24                    Who was born in aguascalientes?
# 25                   What is an album by herb alpert?
# 26                   what is angie estes's profession
# 27             what song was on the recording indiana
# 28     what position does josé francisco torres play?
# 29                where was held for british columbia
# 30    which event took place in italia (roman empire)
# 31              Who did the music for the film taffin
# 32                what male actor was born in  warsaw
# 33  What's an album that the philharmonia orchestr...
# 34     what kind of school is holy cross high school?
# 35                What kind of release was collection
# 36                   What would be a indie rock album
# 37                       How was phrenology released?
# 38                       How was phrenology released?
# 39                       who was also born in jakarta
# 40                 Where is buckingham palace located
# 41                             Who was born in prague
# 42  what country released  she gets out the scrapbook
# 43    What is a recording off the release to the sea?
# 44                 what type of album is  cherry 2000
# 45          Which country is archibald campbell from?
# 46     who is a fictional character that is a gambler
# 47             What is a book written about election?
# 48          what character is of the vampire species?
# 49  What is the name of a game in the gambling ind...
#
#                        gold_ent_name                  query_text  \
# 0                           fearless                    fearless
# 1                         yves klein                  yves klein
# 2       dublin , republic of ireland                      dublin
# 3                             action                 action show
# 4                          jean grae                   jean grae
# 5          carlos argelis gomez pena                carlos gomez
# 6                     pretty in pink              pretty in pink
# 7                            chicago            typeface chicago
# 8                      pee wee reese               pee wee reese
# 9                   one life to live            one life to live
# 10                         carpenter                   carpenter
# 11       acute myocardial infarction       myocardial infarction
# 12                      david ruffin                david ruffin
# 13                           equator                     equator
# 14                       los angeles                 los angeles
# 15                           history                     history
# 16                             viper                       viper
# 17            environmental disaster               environmental
# 18              magical mystery tour        magical mystery tour
# 19                  michael mcdowell            michael mcdowell
# 20                     voodoo lounge               voodoo lounge
# 21                             tokyo                       tokyo
# 22                              loud                        loud
# 23                     western movie                     western
# 24          estado de aguascalientes              aguascalientes
# 25         herbert `` herb '' alpert                 herb alpert
# 26                       angie estes                       angie
# 27                           indiana                     indiana
# 28             jose francisco torres              josé francisco
# 29      province of british columbia            british columbia
# 30                       roman italy         italia roman empire
# 31                            taffin                      taffin
# 32                   miasto warszawa                      warsaw
# 33  new philharmonia orchestra , the      philharmonia orchestra
# 34            holy cross high school      holy cross high school
# 35                        collection                  collection
# 36                        indie rock                  indie rock
# 37                        phrenology                  phrenology
# 38                        phrenology                  phrenology
# 39     daerah khusus ibokota jakarta                     jakarta
# 40        buckingham palace , london           buckingham palace
# 41                            prague                      prague
# 42        she gets out the scrapbook  she gets out the scrapbook
# 43                        to the sea                  to the sea
# 44                       cherry 2000                 cherry 2000
# 45                archibald campbell          archibald campbell
# 46                 steven sharpe iii                     gambler
# 47                          election                    election
# 48                          vampires                     vampire
# 49                          gambling                    gambling
#
#                                    predicted_ent_name
# 0                                            fearless
# 1                                     yves klein blue
# 2                                              dublin
# 3                                     junit in action
# 4             grae fruits : the jean grae compilation
# 5                                  scott carlos gomez
# 6                                      pretty in pink
# 7                                            typeface
# 8   pee wee & jackie : pee wee reese & jackie robi...
# 9                 lady in the dark : one life to live
# 10                                          carpenter
# 11                              myocardial infarction
# 12  20th century masters : the millennium collecti...
# 13                                       equator farm
# 14                                        los angeles
# 15                                            history
# 16                                   day of the viper
# 17                            environmental chemistry
# 18                               magical mystery tour
# 19                                   michael mcdowell
# 20                                      voodoo lounge
# 21                         1995-10-28 : tokyo , japan
# 22                                  thinking out loud
# 23                                       epic western
# 24                          asientos , aguascalientes
# 25                          the essential herb alpert
# 26                                         angie bray
# 27                                   abydel , indiana
# 28                            jose francisco lafuente
# 29                     fort nelson , british columbia
# 30                           pigs of the roman empire
# 31                                    amandine taffin
# 32                                             warsaw
# 33  tristan und isolde ( chorus of the royal opera...
# 34                             holy cross high school
# 35                          the definitive collection
# 36  red hot + bothered : the indie rock guide to d...
# 37                                         phrenology
# 38                                         phrenology
# 39                                   jakarta monorail
# 40                                  buckingham palace
# 41  smetana : ma vlast / the bartered bride / hako...
# 42                         she gets out the scrapbook
# 43                                  riders to the sea
# 44                     cherry 2000 / the house of god
# 45                                 archibald campbell
# 46                                        the gambler
# 47         united states presidential election , 1924
# 48                           buffy the vampire slayer
# 49                   gambling theory and other topics

# %%
df.to_csv('incorrect_ents_without_rel_correction.csv')
